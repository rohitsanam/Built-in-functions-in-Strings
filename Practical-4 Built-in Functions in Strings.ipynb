# %%
a= 'rohit'

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
a.capitalize()
# Out:
# 'Rohit'

# %%
a = "ROHIT"

# %%
a.casefold()
# Out:
# 'rohit'

# %%
a.center(14)
# Out:
# '    ROHIT     '

# %%
a = 'Rohitohit'

# %%
a.count('o')
# Out:
# 2

# %%
a.endswith('t')
# Out:
# True

# %%
a.find('o')
# Out:
# 1

# %%
a.index('o')
# Out:
# 1

# %%
a ='rohit'

# %%
a.isalnum()
# Out:
# True

# %%
a ='rohit123'

# %%
a.isalnum()
# Out:
# True

# %%
b = '123'

# %%
b.isalnum()
# Out:
# True

# %%
a = '#@!'

# %%
a.isalnum()
# Out:
# False

# %%
a.isascii()
# Out:
# True

# %%
a.isdecimal()
# Out:
# False

# %%
a.isdigit()
# Out:
# False

# %%
"rohit"
# Out:
# 'rohit'

# %%
"rohit".isidentifier()
# Out:
# True

# %%
a.islower()
# Out:
# False

# %%
a ="123"

# %%
a.isnumeric()
# Out:
# True

# %%
a.isprintable()
# Out:
# True

# %%
a.isspace()
# Out:
# False

# %%
a="Rohit"

# %%
a.istitle()
# Out:
# True

# %%
a.isupper()
# Out:
# False

# %%
a
# Out:
# 'Rohit'

# %%
'/'.join()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-bb82aeec90fe> in <module>
# ----> 1 '/'.join()
#
# TypeError: join() takes exactly one argument (0 given)

# %%
a.ljust(11)

# %%
a.lower()

# %%
a = "    rohit      "

# %%
a.lstrip()

# %%
a.rstrip()

# %%
a.replace('r','t')

# %%
a.split('r')

# %%
a.startswith('r')

# %%
a

# %%
a.strip()

# %%
a ='RoHiT'

# %%
a.swapcase()

# %%
a.title()

# %%
a.upper()

# %%
a.zfill(11)

# %%
a = 1
b =2
c = a+b
print("The sum of {} and {} is {}".format(a,b,c))

# %%
txt1 = "My name is {fname}, I'm {age} years old".format(fname = "John", age = 36)

# %%
txt1

# %%
txt2 = "My name is {0}, I'm {1}".format("John",36)
txt2

# %%
txt2 = "My name is {a}, I'm {b}".format(a="John",b=36)
txt2

# %%
txt3 = "My name is {}, I'm {}".format("John",36)
